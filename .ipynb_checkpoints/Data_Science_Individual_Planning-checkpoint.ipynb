# %%
library(tidyverse)
library(tidymodels)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.

# %% [markdown]
# ## 1. Data Description

# %%
players <- read_csv("players.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
summary(players)
# Out:
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#
#      name              gender               Age
#  Length:196         Length:196         Min.   : 9.00
#  Class :character   Class :character   1st Qu.:17.00
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.14
#                                        3rd Qu.:22.75
#                                        Max.   :58.00
#                                        NA's   :2

# %% [markdown]
# ### Players dataset
# - The Players dataset contains information about individual players.
# - Each row corresponds to its own observation and a unique player, where there are 196 players and 7 variables.
# - Variables include:
# - experience level, whether they are a pro, amateur, or veteran
# - subscription status, true or false
# - hashed email, to identify each player
# - number of hours played,
# - name
# - gender
# - age
#
#
# For the numeric variables, the mean for hours played is 5.85 hours. The mean age is 21 years.
# The rest are categorical variables, meaning we cannot find a mean for them.
# The Age variable is missing 2 values, which could impact the mean.

# %%
sessions <- read_csv("sessions.csv")
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
summary(sessions)
# Out:
#  hashedEmail         start_time          end_time         original_start_time
#  Length:1535        Length:1535        Length:1535        Min.   :1.712e+12
#  Class :character   Class :character   Class :character   1st Qu.:1.716e+12
#  Mode  :character   Mode  :character   Mode  :character   Median :1.719e+12
#                                                           Mean   :1.719e+12
#                                                           3rd Qu.:1.722e+12
#                                                           Max.   :1.727e+12
#
#  original_end_time
#  Min.   :1.712e+12
#  1st Qu.:1.716e+12
#  Median :1.719e+12
#  Mean   :1.719e+12
#  3rd Qu.:1.722e+12
#  Max.   :1.727e+12
#  NA's   :2

# %% [markdown]
# ### Sessions Dataset
# The sessions dataset contains information about individual gaming sessions for each player.
# There are 1535 sessions and 5 variables, where each row corresponds to one session.
# The variables are the following:
# - hashed email, which identifies the player
# - start time, when the session started
# - end time, when the session ended
# - original start time, the start time in milliseconds
# - original end time, the end time in milliseconds
#
# - The mean for the original start time is 1.719e+12, and the mean for the original end time is 1.719e+12.

# %% [markdown]
# ## 2. Questions

# %% [markdown]
# The broad question I will be addressing is:
# Question 2: We would like to know which "kinds" of players are most likely to contribute a large amount of data so that we can target those players in our recruiting efforts.
#
# - The specific question I have formulated for this is "Can the subscription status predict the number of hours they play in the players dataset?"
# - The players dataset will help address this question because it contains information about each player's subscription status (TRUE/FALSE), and the number of hours they have played (played_hours).
# - The subscription status could tell us whether having a subscription will lead to more hours played or if it does not affect it much.

# %% [markdown]
# ## 3. Exploratory Data Analysis and Visualization

# %% [markdown]
# Both players.csv and sessions.csv are already tidy, so additional wrangling is not necessary.

# %% [markdown]
# The mean values in table format:

# %% [markdown]
# Players.csv
# | Variable     | Mean |
# |--------------|------|
# | played_hours | 5.85 |
# | Age          | 21.14|

# %% [markdown]
# Sessions:
# | Variable            | Mean      |
# |---------------------|-----------|
# | original_start_time | 1.719e+12 |
# | original_end_time   | 1.719e+12 |

# %% [markdown]
# Visualizations

# %% [markdown]
# Players.csv

# %%
options(repr.plot.width = 8, repr.plot.height = 6)

ggplot(players, aes(x= subscribe))+
    geom_bar(fill = "steelblue")+
    labs(title = "The number of players and their subscription status", x = "Subscription Status", y = "Number of Players")+
    theme(text = element_text( size = 13))
# Out:
# plot without title

# %% [markdown]
# This visualization shows me that the number of people not subscribed is much more than those who are subscribed.

# %%
options(repr.plot.width = 8, repr.plot.height = 6)

ggplot(players, aes(x = Age, y = played_hours, color = subscribe))+
    geom_point()+
    labs(title = "Age vs Hours Played", x= "Age (Years)", y = "Hours Played", color = "Subscription status") +

theme(text = element_text( size = 13))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Although the pattern is not very strong, we can see that generally, younger people play more compared to those who are older. However, we also have to note that there are more younger players compared to those older.

# %% [markdown]
# ## 4. Methods and Plan

# %% [markdown]
# 1. I think linear regression is suitable for this because the response variable (played_hours) is numeric. KNN classification would not work because we are not predicting a categorical variable. Linear regression would allow us to predict a numeric value, and it is simple and the most appropriate in this situation. It is also consistent in the way that even if there is less data as we go on, unlike KNN regression, which can be sensitive to the amount of data.
# 2. Some assumptions we would need to make first are that the numeric variables are linear. We would also assume each player/observation is independent of the others.
# 3. Some potential limitations include that if the relationship between subscription status and hours played is not linear, the model may not be the best fit. The other variables, such as age or experience, could result in a more accurate answer.
# 4. I will use the RMSPE to measure how far the model's predictions are from the actual test data.
# 5. I will split the data into training and testing sets. 70% training and 30% testing. Testing will be used to fit the model, and the testing set will be used to see how well the model predicts the new data.
