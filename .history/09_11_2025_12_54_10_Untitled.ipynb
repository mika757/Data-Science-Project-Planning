# %%
library(tidyverse)
library(tidymodels)

# %%
## 1. Data Description

# %%
players <- read_csv("players.csv")

# %%
summary(players)

# %%
sessions <- read_csv("sessions.csv")

# %%
summary(sessions)

# %%
# The Players dataset contains information about individual players on a Minecraft server. Each row corresponds to is own observation and a unique player, it includes variables such as expererience level, subscriptions status, hashed email, number of hours played, name, gender and age. This dataset will help us explore each players characteristics and behaviours that will be relavent to our question. There are 196 players and 7 variables
